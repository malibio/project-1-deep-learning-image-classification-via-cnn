# %% [markdown]
# ### Import the CNN Util and libraries needed
# We have the util to make it easy to create and try new variations of the CNN model and be consistent with how we're analyzing and evaluating it.

# %%
# Import necessary libraries
import cnn_utils
from keras import layers, models
from keras.src.legacy.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Load the data

# %%
data_dict = cnn_utils.load_cifar10_from_tar()
# Out:
# CIFAR-10 tar file not found at cifar-10-python.tar
# Downloading CIFAR-10 data...
# Download completed!
# Loading CIFAR-10 data...
# Loading training batch 1...
# Loading training batch 2...
# Loading training batch 3...
# Loading training batch 4...
# Loading training batch 5...
# Loading test data...
# Raw data loaded successfully!
# Training data shape: (50000, 3072)
# Test data shape: (10000, 3072)
# Label names: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ### Preporcess the data

# %%
data = cnn_utils.preprocess_data(data_dict)
# Out:
# Preprocessing data...
# Preprocessing completed!
# Training: (45000, 32, 32, 3), Validation: (5000, 32, 32, 3), Test: (10000, 32, 32, 3)

# %% [markdown]
# ### Let's do a quick visualization of sample images (to also ensure we still have the correct shape)

# %%
cnn_utils.visualize_data_samples(data)

# %% [markdown]
# ### Data Augmentation
#
# Moderate geometric augmentation that applies realistic transformations to training images:
# - Rotation (±15°), shifting (10% in each direction), and zooming (±10%) simulate natural camera angle and distance variations
# - Horizontal flipping doubles the dataset by creating mirror images (works well for CIFAR-10 since objects like cars/planes look realistic when flipped)

# %%
def create_augmentation():
    return ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        zoom_range=0.1
    )

augmentation = create_augmentation()
augmentation.fit(data['X_train'])

# %% [markdown]
# ### Let's define our CNN model (architecture)
# Deeper, more sophisticated architecture for higher accuracy
# Structure:
# - 3 convolutional blocks (64→128→256 filters)
# - BatchNormalization after each conv layer
# - Progressive dropout (0.3→0.4→0.5)
# - Large dense layer (512 neurons)

# %%
def create_cnn_model(input_shape=(32, 32, 3), num_classes=10):
    model = models.Sequential()

    # Block 1
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(layers.Dropout(0.3))

    # Block 2
    model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(layers.Dropout(0.4))

    # Block 3
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(layers.Dropout(0.5))

    # Dense layers
    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(num_classes, activation='softmax'))

    return model

# %%
model = create_cnn_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

cnn_utils.print_model_summary(model)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ============================================================
# MODEL ARCHITECTURE
# ============================================================
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,253,834 (12.41 MB)
#  Trainable params: 3,251,018 (12.40 MB)
#  Non-trainable params: 2,816 (11.00 KB)
# 📊 Total Parameters: 3,253,834

# %% [markdown]
# ### Now let's train the model

# %%
history = cnn_utils.train_model(model, data, augmentation=augmentation)
# Out:
# Starting model training...
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 46s 46ms/step - accuracy: 0.3114 - loss: 2.2497 - val_accuracy: 0.4182 - val_loss: 1.8032
# Epoch 2/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.5341 - loss: 1.3240 - val_accuracy: 0.5776 - val_loss: 1.1950
# Epoch 3/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.6303 - loss: 1.0473 - val_accuracy: 0.7098 - val_loss: 0.8373
# Epoch 4/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.6763 - loss: 0.9158 - val_accuracy: 0.6862 - val_loss: 0.9216
# Epoch 5/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.7066 - loss: 0.8404 - val_accuracy: 0.7186 - val_loss: 0.8697
# Epoch 6/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.7265 - loss: 0.7836 - val_accuracy: 0.6862 - val_loss: 1.0679
# Epoch 7/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.7465 - loss: 0.7355 - val_accuracy: 0.7224 - val_loss: 0.8714
# Epoch 8/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.7635 - loss: 0.6816 - val_accuracy: 0.7932 - val_loss: 0.6077
# Epoch 9/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.7735 - loss: 0.6606 - val_accuracy: 0.7896 - val_loss: 0.6270
# Epoch 10/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.7824 - loss: 0.6274 - val_accuracy: 0.7710 - val_loss: 0.7014
# Epoch 11/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8000 - loss: 0.5840 - val_accuracy: 0.8250 - val_loss: 0.5317
# Epoch 12/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8038 - loss: 0.5699 - val_accuracy: 0.8146 - val_loss: 0.5607
# Epoch 13/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8087 - loss: 0.5521 - val_accuracy: 0.8478 - val_loss: 0.4616
# Epoch 14/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8150 - loss: 0.5324 - val_accuracy: 0.8106 - val_loss: 0.5901
# Epoch 15/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8222 - loss: 0.5142 - val_accuracy: 0.8314 - val_loss: 0.5019
# Epoch 16/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8245 - loss: 0.5084 - val_accuracy: 0.8446 - val_loss: 0.4462
# Epoch 17/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8371 - loss: 0.4774 - val_accuracy: 0.8328 - val_loss: 0.5043
# Epoch 18/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8358 - loss: 0.4776 - val_accuracy: 0.8336 - val_loss: 0.5141
# Epoch 19/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8381 - loss: 0.4673 - val_accuracy: 0.8266 - val_loss: 0.5343
# Epoch 20/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8468 - loss: 0.4458 - val_accuracy: 0.8630 - val_loss: 0.4075
# Epoch 21/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8491 - loss: 0.4340 - val_accuracy: 0.8646 - val_loss: 0.4060
# Epoch 22/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8460 - loss: 0.4458 - val_accuracy: 0.8600 - val_loss: 0.4191
# Epoch 23/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8526 - loss: 0.4231 - val_accuracy: 0.8656 - val_loss: 0.3937
# Epoch 24/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8578 - loss: 0.4188 - val_accuracy: 0.8684 - val_loss: 0.3940
# Epoch 25/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8605 - loss: 0.4157 - val_accuracy: 0.8670 - val_loss: 0.3836
# Epoch 26/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8603 - loss: 0.4057 - val_accuracy: 0.8646 - val_loss: 0.4162
# Epoch 27/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8642 - loss: 0.3964 - val_accuracy: 0.8648 - val_loss: 0.4158
# Epoch 28/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8669 - loss: 0.3870 - val_accuracy: 0.8900 - val_loss: 0.3275
# Epoch 29/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8702 - loss: 0.3731 - val_accuracy: 0.8622 - val_loss: 0.4146
# Epoch 30/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8667 - loss: 0.3852 - val_accuracy: 0.8794 - val_loss: 0.3763
# Epoch 31/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8731 - loss: 0.3715 - val_accuracy: 0.8458 - val_loss: 0.4904
# Epoch 32/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8711 - loss: 0.3683 - val_accuracy: 0.8626 - val_loss: 0.4375
# Epoch 33/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8752 - loss: 0.3623 - val_accuracy: 0.8826 - val_loss: 0.3419
# Epoch 34/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8744 - loss: 0.3600 - val_accuracy: 0.8686 - val_loss: 0.4050
# Epoch 35/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8781 - loss: 0.3519 - val_accuracy: 0.8632 - val_loss: 0.4407
# Epoch 36/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8791 - loss: 0.3480 - val_accuracy: 0.8848 - val_loss: 0.3514
# Epoch 37/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8851 - loss: 0.3334 - val_accuracy: 0.8812 - val_loss: 0.3567
# Epoch 38/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8813 - loss: 0.3372 - val_accuracy: 0.8918 - val_loss: 0.3296
# Epoch 39/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8848 - loss: 0.3320 - val_accuracy: 0.8796 - val_loss: 0.3716
# Epoch 40/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8860 - loss: 0.3301 - val_accuracy: 0.8810 - val_loss: 0.3791
# Epoch 41/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.8924 - loss: 0.3168 - val_accuracy: 0.8840 - val_loss: 0.3671
# Epoch 42/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8862 - loss: 0.3293 - val_accuracy: 0.8716 - val_loss: 0.3999
# Epoch 43/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8863 - loss: 0.3243 - val_accuracy: 0.8966 - val_loss: 0.3091
# Epoch 44/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8925 - loss: 0.3109 - val_accuracy: 0.8886 - val_loss: 0.3249
# Epoch 45/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8913 - loss: 0.3161 - val_accuracy: 0.8710 - val_loss: 0.4060
# Epoch 46/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8953 - loss: 0.3037 - val_accuracy: 0.8970 - val_loss: 0.3281
# Epoch 47/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8933 - loss: 0.3074 - val_accuracy: 0.8996 - val_loss: 0.3104
# Epoch 48/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8932 - loss: 0.3042 - val_accuracy: 0.8956 - val_loss: 0.3153
# Epoch 49/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8953 - loss: 0.3032 - val_accuracy: 0.8786 - val_loss: 0.3779
# Epoch 50/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.8944 - loss: 0.3011 - val_accuracy: 0.8472 - val_loss: 0.5104
# Training completed in 1183.61 seconds

# %% [markdown]
# ### Let's show the evaluation result

# %%
cnn_utils.evaluate_model(model, data, history)
# Out:
# ============================================================
# MODEL EVALUATION
# ============================================================
# 🎯 Final Test Results:
#    Test Accuracy: 0.8910
#    Test Loss: 0.3410
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.91      0.89      0.90      1000
#   automobile       0.96      0.93      0.95      1000
#         bird       0.91      0.82      0.86      1000
#          cat       0.88      0.70      0.78      1000
#         deer       0.88      0.92      0.90      1000
#          dog       0.84      0.86      0.85      1000
#         frog       0.88      0.96      0.92      1000
#        horse       0.88      0.94      0.91      1000
#         ship       0.95      0.92      0.93      1000
#        truck       0.83      0.98      0.90      1000
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000
